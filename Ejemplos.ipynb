# %% [markdown]
# # Título del programa

# %% [markdown]
# ## Subtítulo del programa

# %% [markdown]
# El primer código de este programa.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
7+6
# Out:
# 13

# %%
# Comentario
print("Hola a todos!")
# Out:
# Hola a todos!

# %% [markdown]
# # Título número 2

# %%
x = 49.3

# %%
x
# Out:
# 49.3

# %%
y = 6

# %%
y
# Out:
# 6

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %% [markdown]
# # Título número 3

# %%
z = int(y)
z
# Out:
# 5

# %%
z = round(y)
z
# Out:
# 6

# %%
z = float(y)
z
# Out:
# 6.0

# %%
type(z)
# Out:
# float

# %% [markdown]
# #Clases en Python

# %%
class Persona:
  def __init__(self, nombre, edad):
self.nombre = nombre
  self.edad = edad
def esmayoredad(self):
  if self.edad>=18:
    return True
  else:
    return False
def setedad(self,edad):
    self.edad = edad:
def getedad(self):
    return self.edad

p1 = Persona("Kevin", 26)
print(p1.nombre)
print(p1.edad)
p1.esmayoredad()
p1.setedad(13)
print(p1.getedad())
p1.esmayoredad()
# Out:
#   File "<ipython-input-7-440dc0c6d832>", line 3
#     self.nombre = nombre
#                         ^
# IndentationError: expected an indented block

# %%
4<5
# Out:
# True

# %% [markdown]
# #Bucles

# %% [markdown]
# ## While

# %% [markdown]
# Imprmir los números enteros menores de 10

# %%
numero = 1
while numero<10:

  print(numero)
  numero = numero+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
suma=0
continuar=True
while continuar:

input_usuario= input("Ingrese un número ('exit' para terminar): ")

if input_usuario == 'exit':
  continuar= False

else:
numero=input_usuario
suma=suma+numero
print(f"La suma es {suma}")

print(f"La suma final es {suma}: ")
# Out:
#   File "<ipython-input-16-fd97e5c1ec58>", line 5
#     input_usuario= input("Ingrese un número ('exit' para terminar): ")
#                 ^
# IndentationError: expected an indented block

# %% [markdown]
# #Continue

# %%
num =0
while num<10:

  num=num+1

  if num %2 ==0:
    continue
print(num)
# Out:
# 10

# %% [markdown]
# ##Blackjack

# %% [markdown]
# El jugador obtiene una carta y va sumandolas hasta obtener el número 21 o el más cercano posible

# %%
import random
random.randint(1,13)
# Out:
# 8

# %%
suma = 0

while suma <=21:

carta = random.randint(1,13)
suma = suma + carta

print(f"La carta obtenida es {carta}")
print(f"La suma de cartas es {suma}")

if suma == 21:
  print("BLACKJACK!")
  break

  elif:
    opcion = input("Desea obtener otra carta? (S/N): ")
    if opcion == "N":
      print(f"La suma final de cartas es {suma}")
      break
# Out:
#   File "<ipython-input-28-a50c46f965bc>", line 5
#     carta = random.randint(1,13)
#         ^
# IndentationError: expected an indented block

# %% [markdown]
# Dataframes,series e indices

# %% [markdown]
# #Datraframes

# %%
import pandas
pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
pokemon = ["Bulbasur", "Squirtle", "Charizard", "Picachu", "Onix", "Geodude", "Vulpix", "Starmie"]
types = ["Grass pioson", "Water", "Fire Flying", "Electric", "Rock Ground", "Rock Ground", "Fire"]
master = ["Ash", "Ash", "Ash", "Ash", "Brock", "Bock", "Misty", "Misty"]
pokedex_number= [1, 4, 7, 25, 95, 74, 37, 121]

# %%
pandas.DataFrame({'pokemon': pokemon,
                  'type' : types,
                  'master' : master,
                  'number' : pokedex_number})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-57a0cccddee2> in <module>()
#       2                   'type' : types,
#       3                   'master' : master,
# ----> 4                   'number' : pokedex_number})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# ...
